# %%
### we will use lama index and create a simple RAG system to test the application for our PDF data.
import os
import sys
import PyPDF2 as pdf
import os

os.environ['OPENAI_API_KEY'] = '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'

### we will use the env file to store the API key and use it in the application.
#os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_KEY')

path = 'dataset/data1.pdf'
reader = pdf.PdfReader(path)

data = reader.pages[2].extract_text()
print(data)
# Out:
# JPMORGAN CHASE & CO.
# CONSOLIDATED FINANCIAL HIGHLIGHTS
# (in millions, except per share and ratio data)
# QUARTERLY TRENDS NINE MONTHS ENDED SEPTEMBER 30,
# 3Q23 Change 2023 Change
# SELECTED INCOME STATEMENT DATA 3Q23 2Q23 1Q23 4Q22 3Q22 2Q23 3Q22 2023 2022 2022
# Reported Basis
# Total net revenue $ 39,874 $ 41,307 $ 38,349 $ 34,547 $ 32,716 (3)% 22 % $ 119,530 $ 94,148 27 %
# Total noninterest expense 21,757 20,822 20,107 19,022 19,178 4 13 62,686 57,118 10
# Pre-provision profit (a) 18,117 20,485 18,242 15,525 13,538 (12) 34 56,844 37,030 54
# Provision for credit losses 1,384 2,899 2,275 2,288 1,537 (52) (10) 6,558 4,101 60
# NET INCOME 13,151 14,472 12,622 11,008 9,737 (9) 35 40,245 26,668 51
# Managed Basis (b)
# Total net revenue 40,686 42,401 39,336 35,566 33,491 (4) 21 122,423 96,711 27
# Total noninterest expense 21,757 20,822 20,107 19,022 19,178 4 13 62,686 57,118 10
# Pre-provision profit (a) 18,929 21,579 19,229 16,544 14,313 (12) 32 59,737 39,593 51
# ...

# %%
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex

# Create a reader for the directory
reader = SimpleDirectoryReader(input_files=["dataset/data1.pdf"])
data = reader.load_data()

# %%
data
# Out:
# [Document(id_='8e5a767b-5eab-4be0-a98b-ed8b089df8c0', embedding=None, metadata={'page_label': '1', 'file_name': '/home/tarush/Desktop/work/NEU/GenAIClass/FinGenInsights/dataset/data1.pdf', 'file_path': 'dataset/data1.pdf', 'file_type': 'application/pdf', 'file_size': 677266, 'creation_date': '2024-02-16', 'last_modified_date': '2024-02-16'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='EARNINGS RELEASE FINANCIAL SUPPLEMENT\nTHIRD QUARTER 2023', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...

# %%
index = VectorStoreIndex.from_documents(data)
qe = index.as_query_engine()

# %%
response = qe.query("What is this document about?")
from IPython.display import display, Markdown

display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>This document is an earnings release financial supplement for the third quarter of 2023 by JPMorgan Chase & Co. It includes consolidated financial highlights, statements of income, balance sheets, segment results, capital and other selected balance sheet items, earnings per share information, business segment results, credit-related information, non-GAAP financial measures, and supplemental information on First Republic.</b>

# %%
response = qe.query("Based on document provide me insights as Bullet points about financial status of the speicif quarter. Also give me important tabular data I can plot for visualization.")
from IPython.display import display, Markdown

display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>- Total net revenue decreased by 3% from the previous quarter but increased by 22% compared to the same quarter last year.
# - Total noninterest expense increased by 4% from the previous quarter and 13% compared to the same quarter last year.
# - Net income decreased by 9% from the previous quarter but showed a significant increase of 35% compared to the same quarter last year.
# - Earnings per share (EPS) decreased by 9% from the previous quarter but increased by 38% compared to the same quarter last year.
# - Market capitalization decreased by 1% from the previous quarter but showed a substantial increase of 37% compared to the same quarter last year.
#
# Important tabular data for visualization:
# 1. Quarterly Trends for Total Net Revenue, Total Noninterest Expense, and Net Income for the specified quarter and the previous quarters.
# 2. Earnings per Share (EPS) data for Basic and Diluted EPS for the specified quarter and the previous quarters.
# ...
