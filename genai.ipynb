# %%
import openai 

api_key = "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"
openai.api_key = api_key

messageSummarize = 'Summarise and give insights "CONSOLIDATED STATEMENTS OF INCOME (in millions, except per share and ratio data) QUARTERLY TRENDS NINE MONTHS ENDED SEPTEMBER 30, 3Q23 Change 2023 Change REVENUE 3Q23 2Q23 1Q23 4Q22 3Q22 2Q23 3Q22 2023 2022 2022 Investment banking fees 1722 1513 1649 1418 1674 14 % 3 % 4884 5268 (7) % Principal transactions 6,210 6,910 7,615 4,434 5,383 (10) 15 20,735 15,478 34 Lending- and deposit-related fees 2,039 1,828 1,620 1,655 1,731 12 18 5,487 5,443 1 Asset management fees 3,904 3,774 3,465 3,432 3,495 3 12 11,143 10,664 4 Commissions and other fees 1,705 1,739 1,695 1,574 1,574 (2) 8 5,139 5,007 3 Investment securities losses (669) (900) (868) (874) (959) 26 30 (2,437) (1,506) (62) Mortgage fees and related income 414 278 221 98 314 49 32 913 1,152 (21) Card income 1,209 1,094 1,234 1,226 1,086 11 11 3,537 3,194 11 Other income 614 3,292 1,007 1,392 900 (81) (32) 4,913 2,930 68 Noninterest revenue 17,148 19,528 17,638 14,355 15,198 (12) 13 54,314 47,630 14 Interest income 44,556 41,644 37,004 33,054 25,611 7 74 123,"'

completion = openai.chat.completions.create(model = "gpt-3.5-turbo",  temperature = 0.8,  max_tokens = 2000,  messages = [{"role": "user", "content": messageSummarize}])

print(completion.choices[0].message)
from pprint import pprint 
pprint(completion.choices[0].message.content)
# Out:
# ChatCompletionMessage(content='The consolidated statements of income show the quarterly trends and nine months ended September 30, 2023. \n\nIn terms of revenue, investment banking fees increased by 14% in 3Q23 compared to the previous quarter, and increased by 3% compared to the same quarter in the previous year. For the nine months ended September 30, 2023, investment banking fees decreased by 7% compared to the same period in the previous year.\n\nPrincipal transactions decreased by 10% in 3Q23 compared to the previous quarter, but increased by 15% compared to the same quarter in the previous year. For the nine months ended September 30, 2023, principal transactions increased by 34% compared to the same period in the previous year.\n\nLending- and deposit-related fees increased by 12% in 3Q23 compared to the previous quarter, and increased by 18% compared to the same quarter in the previous year. For the nine months ended September 30, 2023, lending- and deposit-related fees incre
# ...

# %%
from pprint import pprint 
pprint(completion.choices[0].message.content)
# Out:
# ('The consolidated statements of income show the quarterly trends and nine '
#  'months ended September 30, 2023. \n'
#  '\n'
#  'In terms of revenue, investment banking fees increased by 14% in 3Q23 '
#  'compared to the previous quarter, and increased by 3% compared to the same '
#  'quarter in the previous year. For the nine months ended September 30, 2023, '
#  'investment banking fees decreased by 7% compared to the same period in the '
#  'previous year.\n'
#  '\n'
#  'Principal transactions decreased by 10% in 3Q23 compared to the previous '
#  'quarter, but increased by 15% compared to the same quarter in the previous '
#  'year. For the nine months ended September 30, 2023, principal transactions '
#  'increased by 34% compared to the same period in the previous year.\n'
#  '\n'
#  'Lending- and deposit-related fees increased by 12% in 3Q23 compared to the '
#  'previous quarter, and increased by 18% compared to the same quarter in the '
# ...

# %%
message2 = 'Using this summary, provide insights and bulletpoints "Summary:  Consumer, excluding credit card loans 408,769 408,204 311,433 311,375 313,796 — 30 . Credit card loans 196,935 191,348 180,079 185,175 170,462 . Wholesale loans 704,355 700,517 637,384 639,097 628,375 . Total assets $ 3,898,333 $3,868,240 3,665,743 3,773,884 3 % ."'
completion = openai.chat.completions.create(model = "gpt-3.5-turbo",  temperature = 0.8,  max_tokens = 2000,  messages = [{"role": "user", "content": message2}])

from pprint import pprint 
pprint(completion.choices[0].message.content)
# Out:
# ('- The total consumer loans, excluding credit card loans, increased from '
#  '408,204 to 408,769.\n'
#  '- The total credit card loans increased from 191,348 to 196,935.\n'
#  '- Wholesale loans increased from 700,517 to 704,355.\n'
#  '- The total assets of the company increased from $3,868,240 to $3,898,333, '
#  'representing a 3% growth.\n'
#  '- The consumer loan portfolio showed stable growth over the period.\n'
#  '- Credit card loans experienced consistent growth, indicating increased '
#  'lending activity in this segment.\n'
#  '- Wholesale loans also showed a slight increase, indicating growth in '
#  'lending to businesses.\n'
#  "- The company's total assets continued to grow steadily, suggesting overall "
#  'financial stability and growth.')

# %%
import PyPDF2 as pdf
import os

path = 'dataset/data1.pdf'
reader = pdf.PdfReader(path)

data = reader.pages[2].extract_text()
print(data)
# Out:
# JPMORGAN CHASE & CO.
# CONSOLIDATED FINANCIAL HIGHLIGHTS
# (in millions, except per share and ratio data)
# QUARTERLY TRENDS NINE MONTHS ENDED SEPTEMBER 30,
# 3Q23 Change 2023 Change
# SELECTED INCOME STATEMENT DATA 3Q23 2Q23 1Q23 4Q22 3Q22 2Q23 3Q22 2023 2022 2022
# Reported Basis
# Total net revenue $ 39,874 $ 41,307 $ 38,349 $ 34,547 $ 32,716 (3)% 22 % $ 119,530 $ 94,148 27 %
# Total noninterest expense 21,757 20,822 20,107 19,022 19,178 4 13 62,686 57,118 10
# Pre-provision profit (a) 18,117 20,485 18,242 15,525 13,538 (12) 34 56,844 37,030 54
# Provision for credit losses 1,384 2,899 2,275 2,288 1,537 (52) (10) 6,558 4,101 60
# NET INCOME 13,151 14,472 12,622 11,008 9,737 (9) 35 40,245 26,668 51
# Managed Basis (b)
# Total net revenue 40,686 42,401 39,336 35,566 33,491 (4) 21 122,423 96,711 27
# Total noninterest expense 21,757 20,822 20,107 19,022 19,178 4 13 62,686 57,118 10
# Pre-provision profit (a) 18,929 21,579 19,229 16,544 14,313 (12) 32 59,737 39,593 51
# ...

# %%
message2 = 'Using this data of consolidated financials give me 5 bullet points for insights and give tabular data'+data

completion = openai.chat.completions.create(model = "gpt-3.5-turbo",  temperature = 0.8,  max_tokens = 2000,  messages = [{"role": "user", "content": message2}])

from pprint import pprint 
pprint(completion.choices[0].message.content)
# Out:
# ('Insights:\n'
#  '1. JPMorgan Chase & Co. experienced a decrease in total net revenue in the '
#  'third quarter of 2023 compared to the previous quarter, but it still showed '
#  'a significant increase compared to the same period last year.\n'
#  '2. The provision for credit losses has decreased by 52% in the third quarter '
#  'of 2023 compared to the same period last year, indicating improved credit '
#  'quality.\n'
#  '3. Net income has increased by 35% in the third quarter of 2023 compared to '
#  'the same period last year, demonstrating strong profitability.\n'
#  '4. The market capitalization of JPMorgan Chase & Co. has increased by 37% in '
#  'the third quarter of 2023 compared to the same period last year.\n'
#  '5. The return on common equity (ROE) and return on tangible common equity '
#  '(ROTCE) for JPMorgan Chase & Co. have both shown consistent improvement over '
#  "the quarters, indicating effective utilization of shareholders' equity.\n"
#  '\n'
# ...
